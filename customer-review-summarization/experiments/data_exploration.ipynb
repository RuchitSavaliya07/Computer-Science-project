# %% [markdown]
# # Imports & Load Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load raw dataset
df = pd.read_csv("../data/raw/Dataset-SA.csv")

df.head()
# Out:
#                                         product_name product_price Rate  \
# 0  Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    5
# 1  Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    5
# 2  Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    3
# 3  Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    1
# 4  Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    3
#
#             Review                                            Summary  \
# 0           super!  great cooler excellent air flow and for this p...
# 1          awesome              best budget 2 fit cooler nice cooling
# 2             fair  the quality is good but the power of air is de...
# 3  useless product                  very bad product its a only a fan
# 4             fair                                      ok ok product
#
#   Sentiment
# 0  positive
# 1  positive
# 2  positive
# 3  negative
# 4   neutral

# %% [markdown]
# # Dataset Overview

# %%
df.info()
df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205052 entries, 0 to 205051
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   product_name   205052 non-null  object
#  1   product_price  205052 non-null  object
#  2   Rate           205052 non-null  object
#  3   Review         180388 non-null  object
#  4   Summary        205041 non-null  object
#  5   Sentiment      205052 non-null  object
# dtypes: object(6)
# memory usage: 9.4+ MB
#                                              product_name product_price  \
# count                                              205052        205052
# unique                                                958           525
# top     cello Pack of 18 Opalware Cello Dazzle Lush Fi...          1299
# freq                                                 6005          9150
#
#           Rate     Review Summary Sentiment
# count   205052     180388  205041    205052
# ...

# %% [markdown]
# # Missing Values Check

# %%
df.isnull().sum()
# Out:
# product_name         0
# product_price        0
# Rate                 0
# Review           24664
# Summary             11
# Sentiment            0
# dtype: int64

# %% [markdown]
# # Review Length Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
df = pd.read_csv("../data/raw/Dataset-SA.csv")

# Create review length column
df['review_length'] = df['Review'].astype(str).apply(len)

# Plot
plt.figure()
sns.histplot(df['review_length'], bins=50)
plt.title("Distribution of Review Lengths")
plt.xlabel("Number of Characters")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # Sentiment Distribution (if sentiment column exists)

# %%
if 'sentiment' in df.columns:
    sns.countplot(x='sentiment', data=df)
    plt.title("Sentiment Distribution")
    plt.show()
else:
    print("No sentiment labels found in dataset")
# Out:
# No sentiment labels found in dataset

# %% [markdown]
# # Sample Reviews

# %%
df['Review'].sample(5).tolist()
# Out:
# ['great product', 'waste of money!', nan, 'delightful', nan]
